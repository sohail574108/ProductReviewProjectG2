# %% [markdown]
# Product Review Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data01 = pd.read_csv('1429_1.csv')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16688\54649922.py:1: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data01 = pd.read_csv('1429_1.csv')
